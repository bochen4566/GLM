# %%
# !unzip hw3_2.zip

# %%
# !pip install -r hw3/miniwob++/requirements.txt

# %%
# !python hw3/miniwob++/main.py 0 1 chatgpt hw3/miniwob++/result/outputlog1.txt

# %%
# !python hw3/miniwob++/main.py 0 1 model hw3/miniwob++/result/outputlog2.txt

# %%
# !export HUGGINGFACE_API_KEY="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"

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !python hw3/miniwob++/main.py 0 1 meta-llama/Llama-2-7b-chat-hf hw3/miniwob++/result/outputlog2.txt
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# 2024-11-12 02:32:20.961036: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-12 02:32:20.980098: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-12 02:32:20.985876: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python hw3/miniwob++/main.py 0 1 meta-llama/Llama-2-7b-chat-hf hw3/miniwob++/result/outputlog3.txt
# Out:
# Streaming output truncated to the last 5000 lines.
#     raise ValueError("a coroutine was expected, got {!r}".format(main))
# ValueError: a coroutine was expected, got 'Select Lebanon from the scroll list and click Submit.'
#
# 2024-11-12 03:28:52,582 - INFO - {"task": "click-scroll-list", "avg_score": 0.0, "completed": 1}
# INFO:logger:{"task": "click-scroll-list", "avg_score": 0.0, "completed": 1}
# <html> <div| wrap <div| area <span[A]| rgb(0.84,0.92,0.84) > <span[B]| rgb(0.1,0.1,0.9) > <span[C]| rgb(0.63,0.87,0.63) > <span[D]| rgb(0.92,0.1,0.1) > <span[E]| rgb(0.33,0.33,0.93) > <span[F]| rgb(0.94,0.51,0.51) > <span[G]| rgb(0.77,0.93,0.77) > <span[H]| rgb(0.29,0.29,0.63) > <span[I]| rgb(0.84,0.45,0.45) > <span[J]| rgb(0.94,0.22,0.22) > <span[K]| rgb(0.35,0.77,0.35) > <span[L]| rgb(0.8,0.38,0.38) > <button[M]| submit; secondary-action; Submit > > > </html>
#
# You are a helpful assistant that can assist with web navigation tasks.
# ...

# %%
llama2_key = "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"
model_name = "meta-llama/Llama-2-7b-chat-hf"

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import transformers
import torch

model_name = "meta-llama/Meta-Llama-3-8B"
llama3_token = "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"
# Load the model and tokenizer from Hugging Face
tokenizer = AutoTokenizer.from_pretrained(model_name, use_auth_token=llama3_token)
model = AutoModelForCausalLM.from_pretrained(model_name, use_auth_token=llama3_token)

# Set up the pipeline for text generation
llama3_pipeline = pipeline("text-generation", model=model, tokenizer=tokenizer)

# Generate text based on a prompt
prompt = "Explain the principles of quantum computing."
output = llama3_pipeline(prompt, max_length=150, num_return_sequences=1, do_sample=True)

# Print the output
print(output[0]["generated_text"])

# %%
from transformers import pipeline
llama3_pipeline = pipeline("text-generation", model=model, tokenizer=tokenizer, device=0 if torch.cuda.is_available() else -1)

# Generate text based on a prompt
prompt = "Explain the principles of quantum computing."
output = llama3_pipeline(prompt, max_length=150, num_return_sequences=1, do_sample=True)

# Print the output
print(output[0]["generated_text"])
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7a1ef1ff0b4f> in <cell line: 2>()
#       1 from transformers import pipeline
# ----> 2 llama3_pipeline = pipeline("text-generation", model=model, tokenizer=tokenizer, device=0 if torch.cuda.is_available() else -1)
#       3
#       4 # Generate text based on a prompt
# ...

# %%
torch.save(model, "hw3/miniwob++/llms/llama3.pt")

# %%
access_token = "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"
model = "meta-llama/Llama-2-7b-chat-hf"

tokenizer = AutoTokenizer.from_pretrained(model, token=access_token)

model = AutoModelForCausalLM.from_pretrained(
    model,
    token=access_token
)

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    torch_dtype=torch.float16,
    device_map="auto",
)
